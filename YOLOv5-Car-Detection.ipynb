# %% [markdown]
# <a href="https://colab.research.google.com/github/salma-303/YOLOv5-Custom-Training/blob/main/YOLOv5-Car-Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Training YOLOv5 on custom data
# >[Setup](#scrollTo=Zgb515yaVjV-)
#
# >[Create Dataset](#scrollTo=rn0vzzhaZ3w9)
#
# >[Train](#scrollTo=qLceISsSbXbR)
#
# >[Detect](#scrollTo=fw61mZaPDMYe)

# %% [markdown]
# # Setup

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 26.3/78.2 GB disk)

# %% [markdown]
# # Create Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Jp4ntW2VKyYLYrPhUHTf")
project = rf.workspace("skyxperts").project("yolov5-car-detection")
dataset = project.version(2).download("yolov5")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.7/58.7 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 7.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.7/178.7 kB 10.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.1/49.1 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 kB 7.7 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.1
#     Uninstalling pyparsing-3.1.1:
#       Successfully uninstalled pyparsing-3.1.1
#   Attempting uninstall: opencv-python-headless
#     Found existing installation: opencv-python-headless 4.8.0.76
#     Uninstalling opencv-python-headless-4.8.0.76:
#       Successfully uninstalled opencv-python-headless-4.8.0.76
# ...

# %% [markdown]
# # Train

# %%
! python train.py --img 640 --epochs 120 --data data.yaml --weights yolov5s.pt --cache ram
# Out:
# WARNING ⚠️ invalid check_version(3.1.37, ) requested, please check values.
# train: weights=yolov5s.pt, cfg=, data=data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=120, batch_size=16, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# ...

# %% [markdown]
# # Detect

# %%
! python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --source /content/sample3.mp4
# Out:
# Streaming output truncated to the last 5000 lines.
# Object: car - Centroid: (709.00, 524.00) - Confidence: 0.92
# video 1/1 (7778/9011) /content/sample3.mp4: 384x640 2 cars, 7.9ms
# Object: car - Centroid: (609.50, 518.50) - Confidence: 0.51
# Object: car - Centroid: (709.50, 524.50) - Confidence: 0.91
# video 1/1 (7779/9011) /content/sample3.mp4: 384x640 2 cars, 7.9ms
# Object: car - Centroid: (609.50, 518.50) - Confidence: 0.37
# Object: car - Centroid: (711.00, 524.50) - Confidence: 0.93
# video 1/1 (7780/9011) /content/sample3.mp4: 384x640 2 cars, 7.9ms
# Object: car - Centroid: (610.00, 518.50) - Confidence: 0.38
# Object: car - Centroid: (712.50, 524.50) - Confidence: 0.93
# video 1/1 (7781/9011) /content/sample3.mp4: 384x640 2 cars, 11.6ms
# Object: car - Centroid: (610.50, 518.00) - Confidence: 0.31
# Object: car - Centroid: (715.50, 525.00) - Confidence: 0.93
# video 1/1 (7782/9011) /content/sample3.mp4: 384x640 2 cars, 11.4ms
# ...

# %%
# !zip -r '/content/version2.zip' '/content/yolov5/runs/train/exp'
# Out:
#   adding: content/yolov5/runs/train/exp/ (stored 0%)
#   adding: content/yolov5/runs/train/exp/opt.yaml (deflated 49%)
#   adding: content/yolov5/runs/train/exp/R_curve.png (deflated 20%)
#   adding: content/yolov5/runs/train/exp/train_batch2.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp/results.csv (deflated 86%)
#   adding: content/yolov5/runs/train/exp/hyp.yaml (deflated 45%)
#   adding: content/yolov5/runs/train/exp/train_batch1.jpg (deflated 1%)
#   adding: content/yolov5/runs/train/exp/val_batch0_pred.jpg (deflated 5%)
#   adding: content/yolov5/runs/train/exp/PR_curve.png (deflated 26%)
#   adding: content/yolov5/runs/train/exp/events.out.tfevents.1695399856.823c6cc5c14e.829.0 (deflated 42%)
#   adding: content/yolov5/runs/train/exp/results.png (deflated 9%)
#   adding: content/yolov5/runs/train/exp/F1_curve.png (deflated 18%)
#   adding: content/yolov5/runs/train/exp/labels_correlogram.jpg (deflated 40%)
# ...

# %%
 ! python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img-size 640 --conf 0.4 --source /content/sample2.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/sample2.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Object: car - Centroid: (705.50, 69.00) - Confidence: 0.71
# Object: car - Centroid: (22.00, 82.00) - Confidence: 0.74
# Object: car - Centroid: (127.50, 268.50) - Confidence: 0.84
# ...

# %%
 ! python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img-size 640 --conf 0.4 --source /content/sample.jpg
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/sample.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.4, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# WARNING ⚠️ invalid check_version(5.9.5, ) requested, please check values.
# YOLOv5 🚀 v7.0-224-g6262c7f Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7012822 parameters, 0 gradients, 15.8 GFLOPs
# Object: car - Centroid: (575.50, 350.00) - Confidence: 0.41
# Object: car - Centroid: (106.00, 112.00) - Confidence: 0.72
# Object: car - Centroid: (77.00, 366.00) - Confidence: 0.78
# ...
